# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx")

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx", na_filter=False)

# %%
df
# Out:
#       REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE   DEFECT  \
# 0    1180445  N850GT    2021-08-25     B747-8       PILOT  1427680
# 1    1180448  N850GT    2021-08-28     B747-8       PILOT  1384652
# 2    1180450  N850GT    2021-08-29     B747-8       PILOT  1384657
# 3    1180451  N850GT    2021-08-30     B747-8       PILOT  1384662
# 4    1180452  N850GT    2021-08-30     B747-8       PILOT  1384664
# ..       ...     ...           ...        ...         ...      ...
# 985                            NaT
# 986                            NaT
# 987                            NaT
# 988                            NaT
# 989                            NaT
#
#     DEFECT_ITEM CHAPTER Unnamed: 8  Time  ... DELAY_HOUR DELAY_MINUTES MIS PN  \
# 0             3      72       10.2  10.2  ...
# 1             3      72      10.22  11.2  ...
# 2             2      72      10.24  12.2  ...
# 3             1      72      10.26  13.2  ...
# 4             1      72      10.28  14.2  ...
# ...

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx", na_filter=True)

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx")

# %%
df.isnull()
# Out:
#      REC_ID     AC  REPORTED_DATE  FLEET_TYPE  DEFECT_TYPE  DEFECT  \
# 0     False  False          False       False        False   False
# 1     False  False          False       False        False   False
# 2     False  False          False       False        False   False
# 3     False  False          False       False        False   False
# 4     False  False          False       False        False   False
# ..      ...    ...            ...         ...          ...     ...
# 985    True   True           True        True         True    True
# 986    True   True           True        True         True    True
# 987    True   True           True        True         True    True
# 988    True   True           True        True         True    True
# 989    True   True           True        True         True    True
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8   Time  ...  DELAY_HOUR  DELAY_MINUTES  \
# 0          False    False       False  False  ...        True           True
# ...

# %%
df.isnull().sum()
# Out:
# REC_ID                        933
# AC                            933
# REPORTED_DATE                 933
# FLEET_TYPE                    933
# DEFECT_TYPE                   933
# DEFECT                        933
# DEFECT_ITEM                   933
# CHAPTER                       933
# Unnamed: 8                    933
# Time                          933
# month                         933
# Unnamed: 11                   933
# Unnamed: 12                   933
# Unnamed: 13                   933
# SECTION                       933
# CAUSE_INDICATION              933
# CAUSE_DRIVER_ISSUE            937
# Unnamed: 17                   990
# DEFECT_DESCRIPTION            933
# Unnamed: 19                   990
# 1                               0
# Unnamed: 21                     2
# math                          990
# Unnamed: 23                   990
# Unnamed: 24                   990
# Unnamed: 25                   990
# CAUSE_ACTION                  934
# ...

# %%
df.notnull()
# Out:
#      REC_ID     AC  REPORTED_DATE  FLEET_TYPE  DEFECT_TYPE  DEFECT  \
# 0      True   True           True        True         True    True
# 1      True   True           True        True         True    True
# 2      True   True           True        True         True    True
# 3      True   True           True        True         True    True
# 4      True   True           True        True         True    True
# ..      ...    ...            ...         ...          ...     ...
# 985   False  False          False       False        False   False
# 986   False  False          False       False        False   False
# 987   False  False          False       False        False   False
# 988   False  False          False       False        False   False
# 989   False  False          False       False        False   False
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8   Time  ...  DELAY_HOUR  DELAY_MINUTES  \
# 0           True     True        True   True  ...       False          False
# ...

# %%
df.notnull().sum()
# Out:
# REC_ID                         57
# AC                             57
# REPORTED_DATE                  57
# FLEET_TYPE                     57
# DEFECT_TYPE                    57
# DEFECT                         57
# DEFECT_ITEM                    57
# CHAPTER                        57
# Unnamed: 8                     57
# Time                           57
# month                          57
# Unnamed: 11                    57
# Unnamed: 12                    57
# Unnamed: 13                    57
# SECTION                        57
# CAUSE_INDICATION               57
# CAUSE_DRIVER_ISSUE             53
# Unnamed: 17                     0
# DEFECT_DESCRIPTION             57
# Unnamed: 19                     0
# 1                             990
# Unnamed: 21                   988
# math                            0
# Unnamed: 23                     0
# Unnamed: 24                     0
# Unnamed: 25                     0
# CAUSE_ACTION                   56
# ...

# %%
df.dropna(axis=1)
# Out:
#          1
# 0      1.1
# 1      1.2
# 2      1.3
# 3      1.4
# 4      1.5
# ..     ...
# 985   99.6
# 986   99.7
# 987   99.8
# 988   99.9
# 989  100.0
#
# [990 rows x 1 columns]

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.dropna(how="any")
# Out:
# Empty DataFrame
# Columns: [REC_ID, AC, REPORTED_DATE, FLEET_TYPE, DEFECT_TYPE, DEFECT, DEFECT_ITEM, CHAPTER, Unnamed: 8, Time, month, Unnamed: 11, Unnamed: 12, Unnamed: 13, SECTION, CAUSE_INDICATION, CAUSE_DRIVER_ISSUE, Unnamed: 17, DEFECT_DESCRIPTION, Unnamed: 19, 1, Unnamed: 21, math, Unnamed: 23, Unnamed: 24, Unnamed: 25, CAUSE_ACTION, CAUSE_SOURCE, RESOLUTION_DESCRIPTION, RESOLVED_DATE, RESOLVED_LOCATION, RESOLUTION_DEFECT, MDDR, DEFECT_DESCRIPTION_PRESENT, MDDR_PRESENT, STATUS, DELAY_TYPE, DELAY_HOUR, DELAY_MINUTES, MIS, PN, SN, PN_DESCRIPTION, POSITION, HOURS_INSTALLED, CYCLES_INSTALLED, DAYS_INSTALLED]
# Index: []
#
# [0 rows x 47 columns]

# %%
df.dropna(axis=1,how="any")
# Out:
#          1
# 0      1.1
# 1      1.2
# 2      1.3
# 3      1.4
# 4      1.5
# ..     ...
# 985   99.6
# 986   99.7
# 987   99.8
# 988   99.9
# 989  100.0
#
# [990 rows x 1 columns]

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.dropna(thresh=1)
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\Cause_code_rahul_6_sept.xlsx")

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.fillna(25)
# Out:
#         REC_ID      AC        REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT  2021-08-25 00:00:00     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT  2021-08-28 00:00:00     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT  2021-08-29 00:00:00     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT  2021-08-30 00:00:00     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT  2021-08-30 00:00:00     B747-8       PILOT  1384664.0
# ..         ...     ...                  ...        ...         ...        ...
# 985       25.0      25                   25         25          25       25.0
# 986       25.0      25                   25         25          25       25.0
# 987       25.0      25                   25         25          25       25.0
# 988       25.0      25                   25         25          25       25.0
# 989       25.0      25                   25         25          25       25.0
#
# ...

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.fillna({"AC":"N550GT", "REPORTED_DATE":"2021-08-25","FLEET_TYPE":"B747-4"})
# Out:
#         REC_ID      AC        REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT  2021-08-25 00:00:00     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT  2021-08-28 00:00:00     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT  2021-08-29 00:00:00     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT  2021-08-30 00:00:00     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT  2021-08-30 00:00:00     B747-8       PILOT  1384664.0
# ..         ...     ...                  ...        ...         ...        ...
# 985        NaN  N550GT           2021-08-25     B747-4         NaN        NaN
# 986        NaN  N550GT           2021-08-25     B747-4         NaN        NaN
# 987        NaN  N550GT           2021-08-25     B747-4         NaN        NaN
# 988        NaN  N550GT           2021-08-25     B747-4         NaN        NaN
# 989        NaN  N550GT           2021-08-25     B747-4         NaN        NaN
#
# ...

# %%
df
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df2=df.fillna(method="ffill")

# %%
df2
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 986  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 987  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 988  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 989  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.fillna(method="pad")
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 986  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 987  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 988  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 989  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df.fillna(method="bfill")
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985        NaN     NaN           NaT        NaN         NaN        NaN
# 986        NaN     NaN           NaT        NaN         NaN        NaN
# 987        NaN     NaN           NaT        NaN         NaN        NaN
# 988        NaN     NaN           NaT        NaN         NaN        NaN
# 989        NaN     NaN           NaT        NaN         NaN        NaN
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df3=df2.fillna(method="bfill")

# %%
df3
# Out:
#         REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE     DEFECT  \
# 0    1180445.0  N850GT    2021-08-25     B747-8       PILOT  1427680.0
# 1    1180448.0  N850GT    2021-08-28     B747-8       PILOT  1384652.0
# 2    1180450.0  N850GT    2021-08-29     B747-8       PILOT  1384657.0
# 3    1180451.0  N850GT    2021-08-30     B747-8       PILOT  1384662.0
# 4    1180452.0  N850GT    2021-08-30     B747-8       PILOT  1384664.0
# ..         ...     ...           ...        ...         ...        ...
# 985  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 986  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 987  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 988  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
# 989  1178444.0  N508KZ    2021-08-31   B747-400    MECHANIC  1356240.0
#
#      DEFECT_ITEM  CHAPTER  Unnamed: 8  Time  ... DELAY_HOUR  DELAY_MINUTES  \
# ...

# %%
df3.to_excel('cause_code.xlsx')

# %%
df_cleaned=pd.read_excel("C:\\Users\\rcmlp.12\\Desktop\\working file\\python path\\cause_code.xlsx")

# %%
df_cleaned
# Out:
#       REC_ID      AC REPORTED_DATE FLEET_TYPE DEFECT_TYPE   DEFECT  \
# 0    1180445  N850GT    2021-08-25     B747-8       PILOT  1427680
# 1    1180448  N850GT    2021-08-28     B747-8       PILOT  1384652
# 2    1180450  N850GT    2021-08-29     B747-8       PILOT  1384657
# 3    1180451  N850GT    2021-08-30     B747-8       PILOT  1384662
# 4    1180452  N850GT    2021-08-30     B747-8       PILOT  1384664
# ..       ...     ...           ...        ...         ...      ...
# 985  1178444  N508KZ    2021-08-31   B747-400    MECHANIC  1356240
# 986  1178444  N508KZ    2021-08-31   B747-400    MECHANIC  1356240
# 987  1178444  N508KZ    2021-08-31   B747-400    MECHANIC  1356240
# 988  1178444  N508KZ    2021-08-31   B747-400    MECHANIC  1356240
# 989  1178444  N508KZ    2021-08-31   B747-400    MECHANIC  1356240
#
#      DEFECT_ITEM  CHAPTER  Report time  Time  ...  \
# 0              3       72        10.20  10.2  ...
# 1              3       72        10.22  11.2  ...
# ...

# %%
x=df_cleaned["AC"]
y=df_cleaned["DEFECT_ITEM"]

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y)
plt.xlabel("Aircraft")
plt.ylabel("Defect Item")
# Out:
# Text(0, 0.5, 'Defect Item')

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
plt.pie(class1_students)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
plt.pie(class1_students, labels=classes)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
colors=["r","b","g","y","b"]
plt.pie(class1_students, labels=classes,explode=explode,colors=colors)
plt.show()
