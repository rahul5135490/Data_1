# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla=pdr.get_data_yahoo('TSLA')
df_tesla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-09-01   23.839333   23.579332   23.741333   23.693333  45742500.0
# 2017-09-05   23.699333   23.059334   23.586666   23.306000  57526500.0
# 2017-09-06   23.398666   22.770666   23.299999   22.968666  61371000.0
# 2017-09-07   23.498667   22.896667   23.065332   23.374001  63588000.0
# 2017-09-08   23.318666   22.820000   23.266001   22.893333  48952500.0
# ...                ...         ...         ...         ...         ...
# 2022-08-25  302.959991  291.600006  302.359985  296.070007  53230000.0
# 2022-08-26  302.000000  287.470001  297.429993  288.089996  56905800.0
# 2022-08-29  287.739990  280.700012  282.829987  284.820007  41864700.0
# 2022-08-30  288.480011  272.649994  287.869995  277.700012  50541800.0
# 2022-08-31  281.250000  271.809998  280.619995  275.609985  51788900.0
#
#              Adj Close
# Date
# 2017-09-01   23.693333
# 2017-09-05   23.306000
# 2017-09-06   22.968666
# 2017-09-07   23.374001
# 2017-09-08   22.893333
# ...                ...
# 2022-08-25  296.070007
# 2022-08-26  288.089996
# 2022-08-29  284.820007
# 2022-08-30  277.700012
# 2022-08-31  275.609985
#
# [1258 rows x 6 columns]

# %%
# Simple moving average(Basically done for smoothning the graph)

# %%
df_tesla["Open"].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:10 days rolling']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla[['Open','Open:10 days rolling']]
# Out:
#                   Open  Open:10 days rolling
# Date
# 2017-09-01   23.741333             23.741333
# 2017-09-05   23.586666             23.664000
# 2017-09-06   23.299999             23.542666
# 2017-09-07   23.065332             23.423333
# 2017-09-08   23.266001             23.391866
# ...                ...                   ...
# 2022-08-25  302.359985            299.455664
# 2022-08-26  297.429993            300.256998
# 2022-08-29  282.829987            298.361328
# 2022-08-30  287.869995            295.981662
# 2022-08-31  280.619995            293.703995
#
# [1258 rows x 2 columns]

# %%
df_tesla[['Open','Open:10 days rolling']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Expanding

# %%
df_tesla['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
10000*10000*10000*10000*10000
# Out:
# 100000000000000000000
